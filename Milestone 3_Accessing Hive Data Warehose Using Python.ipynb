# %%
from pyhive import hive
import pandas as pd

# %%
host_name="localhost"
port=10000
database="default"


def hiveconnection(host_name,port,database):
    conn=hive.Connection(host=host_name,port=port,database=database)
    cur=conn.cursor()
    cur.execute('select * from mudahkl')
    result=cur.fetchall()
    
    return result

output=hiveconnection(host_name,port,database)

df=pd.DataFrame(output)

# %%
df.head(10)
# Out:
#    0                                1                        2  \
# 0  0                   "     OUG    "  "    RM 3 999 000     "
# 1  1         "     Desa ParkCity    "  "    RM 3 300 000     "
# 2  2           "     Wangsa Maju    "    "    RM 590 000     "
# 3  2           "     Wangsa Maju    "    "    RM 590 000     "
# 4  4          "     Ampang Hilir    "    "    RM 460 000     "
# 5  5                "     Cheras    "    "    RM 300 000     "
# 6  6                "     Cheras    "    "    RM 950 000     "
# 7  7  "     Bandar Tasik Selatan    "    "    RM 199 000     "
# 8  8                "     Cheras    "    "    RM 330 000     "
# 9  9                "     Cheras    "    "    RM 519 000     "
#
#                 3                4               5             6  \
# 0  " 8 Bedrooms "  " 8 Bathrooms "      " Houses "  "7000 sq.ft"
# 1  " 4 Bedrooms "  " 3 Bathrooms "      " Houses "  "2379 sq.ft"
# 2  " 4 Bedrooms "  " 2 Bathrooms "  " Apartments "  "1065 sq.ft"
# 3  " 4 Bedrooms "  " 2 Bathrooms "  " Apartments "  "1065 sq.ft"
# 4  " 2 Bedrooms "  " 2 Bathrooms "  " Apartments "   "743 sq.ft"
# 5  " 3 Bedrooms "  " 2 Bathrooms "  " Apartments "   "748 sq.ft"
# 6  " 7 Bedrooms "  " 5 Bathrooms "      " Houses "  "2400 sq.ft"
# 7  " 3 Bedrooms "  " 2 Bathrooms "  " Apartments "   "650 sq.ft"
# 8  " 3 Bedrooms "  " 2 Bathrooms "  " Apartments "  "1075 sq.ft"
# 9  " 4 Bedrooms "  " 3 Bathrooms "  " Apartments "  "1001 sq.ft"
#
#                                                    7            8  \
# 0  "https://www.mudah.my/Happy+Garden+Bungalow+3+...   "Freehold"
# 1  "https://www.mudah.my/Desa+park+city+zenia+end...   "Freehold"
# 2  "https://www.mudah.my/QN+Residence+Jalan+Wangs...  "Leasehold"
# 3  "https://www.mudah.my/QN+Residence+Jalan+Wangs...  "Leasehold"
# 4  "https://www.mudah.my/PANDAN+PERDANA+new+condo...  "Leasehold"
# 5  "https://www.mudah.my/Residensi+Putra+suria+Ba...  "Leasehold"
# 6  "https://www.mudah.my/Taman+Bukit+Segar+Cheras...  "Leasehold"
# 7  "https://www.mudah.my/Pangsapuri+Kos+Rendah+Ba...  "Leasehold"
# 8  "https://www.mudah.my/Cheras+FREEHOLD+condo+fo...   "Freehold"
# 9  "https://www.mudah.my/Ixora+Residence+Cheras+S...  "Leasehold"
#
#                 9   10              11
# 0  "Non Bumi Lot"  NaN            "NA"
# 1  "Non Bumi Lot"  NaN  "Swimming Pool
# 2  "Non Bumi Lot"  2.0  "Swimming Pool
# 3  "Non Bumi Lot"  2.0  "Swimming Pool
# 4  "Non Bumi Lot"  1.0  "Swimming Pool
# 5      "Bumi Lot"  1.0    "Mini Market
# 6  "Non Bumi Lot"  NaN    "Mini Market
# 7      "Bumi Lot"  NaN            "NA"
# 8  "Non Bumi Lot"  1.0  "Swimming Pool
# 9  "Non Bumi Lot"  2.0  "Swimming Pool
